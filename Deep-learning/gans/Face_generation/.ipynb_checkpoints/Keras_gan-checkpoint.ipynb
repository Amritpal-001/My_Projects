# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_Keras_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# youtube video - https://www.youtube.com/watch?v=T-MCludVNn4

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 7: Generative Adversarial Networks**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 7 Material
#
# * Part 7.1: Introduction to GANS for Image and Data Generation [[Video]](https://www.youtube.com/watch?v=0QnCH6tlZgc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_1_gan_intro.ipynb)
# * **Part 7.2: Implementing a GAN in Keras** [[Video]](https://www.youtube.com/watch?v=T-MCludVNn4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_2_Keras_gan.ipynb)
# * Part 7.3: Face Generation with StyleGAN and Python [[Video]](https://www.youtube.com/watch?v=Wwwyr7cOBlU&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_3_style_gan.ipynb)
# * Part 7.4: GANS for Semi-Supervised Learning in Keras [[Video]](https://www.youtube.com/watch?v=ZPewmEu7644&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_4_gan_semi_supervised.ipynb)
# * Part 7.5: An Overview of GAN Research [[Video]](https://www.youtube.com/watch?v=cvCvZKvlvq4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_5_gan_research.ipynb)

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# # Part 7.2: Implementing DCGANs in Keras
#
# Paper that described the type of DCGAN that we will create in this module. [[Cite:radford2015unsupervised]](https://arxiv.org/abs/1511.06434) This paper implements a DCGAN as follows:
#
# * No pre-processing was applied to training images besides scaling to the range of the tanh activation function [-1, 1].
# * All models were trained with mini-batch stochastic gradient descent (SGD) with a mini-batch size of 128.
# * All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
# * In the LeakyReLU, the slope of the leak was set to 0.2 in all models.
# * we used the Adam optimizer(Kingma & Ba, 2014) with tuned hyperparameters. We found the suggested learning rate of 0.001, to be too high, using 0.0002 instead.
# * Additionally, we found leaving the momentum term $\beta{1}$ at the suggested value of 0.9 resulted in training oscillation and instability while reducing it to 0.5 helped stabilize training.
#
# The paper also provides the following architecture guidelines for stable Deep Convolutional GANs:
#
# * Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# * Use batchnorm in both the generator and the discriminator.
# * Remove fully connected hidden layers for deeper architectures.
# * Use ReLU activation in generator for all layers except for the output, which uses Tanh.
# * Use LeakyReLU activation in the discriminator for all layers.
#
# While creating the material for this module I used a number of Internet resources, some of the most helpful were:
#
# * [Deep Convolutional Generative Adversarial Network (TensorFlow 2.0 example code)](https://www.tensorflow.org/tutorials/generative/dcgan)
# * [Keep Calm and train a GAN. Pitfalls and Tips on training Generative Adversarial Networks](https://medium.com/@utk.is.here/keep-calm-and-train-a-gan-pitfalls-and-tips-on-training-generative-adversarial-networks-edd529764aa9)
# * [Collection of Keras implementations of Generative Adversarial Networks GANs](https://github.com/eriklindernoren/Keras-GAN)
# * [dcgan-facegenerator](https://github.com/platonovsimeon/dcgan-facegenerator), [Semi-Paywalled Article by GitHub Author](https://medium.com/datadriveninvestor/generating-human-faces-with-keras-3ccd54c17f16)
#
# The program created next will generate faces similar to these.  While these faces are not perfect, they demonstrate how we can construct and train a GAN on or own.  Later we will see how to import very advanced weights from nVidia to produce high resolution, realistic looking faces. Figure 7.GAN-GRID shows images from GAN training.
#
# **Figure 7.GAN-GRID: GAN Neural Network Training**
# ![GAN](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/gan-3.png "GAN Images")
#
# As discussed in the previous module, the GAN is made up of two different neural networks: the discriminator and the generator.  The generator generates the images, while the discriminator detects if a face is real or was generated.  These two neural networks work as shown in Figure 7.GAN-EVAL:
#
# **Figure 7.GAN-EVAL: Evaluating GANs**
# ![GAN](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/gan_fig_1.png "GAN")
#
# The discriminator accepts an image as its input and produces number that is the probability of the input image being real.  The generator accepts a random seed vector and generates an image from that random vector seed. An unlimited number of new images can be created by providing additional seeds.

# %% [markdown]
# I suggest running this code with a GPU, it will be very slow on a CPU alone.  The following code mounts your Google drive for use with Google CoLab.  If you are not using CoLab, the following code will not work.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %% [markdown]
# The following packages will be used to implement a basic GAN system in Python/Keras.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %% [markdown]
# These are the constants that define how the GANs will be created for this example.  The higher the resolution, the more memory that will be needed.  Higher resolution will also result in longer run times.  For Google CoLab (with GPU) 128x128 resolution is as high as can be used (due to memory).  Note that the resolution is specified as a multiple of 32.  So **GENERATE_RES** of 1 is 32, 2 is 64, etc.
#
# To run this you will need training data.  The training data can be any collection of images.  I suggest using training data from the following two locations.  Simply unzip and combine to a common directory.  This directory should be uploaded to Google Drive (if you are using CoLab). The constant **DATA_PATH** defines where these images are stored.
#
# The source data (faces) used in this module can be found here:
#
# * [Kaggle Faces Data New](https://www.kaggle.com/gasgallo/faces-data-new)
# * [Kaggle Lag Dataset: Dataset of faces, from more than 1k different subjects](https://www.kaggle.com/gasgallo/lag-dataset)

# %%
# !unzip -q  '/content/drive/My Drive/projects/FaceData8000.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#                  unable to process FaceData8000/cferdo.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cferdo.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cgboyc.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/chr_exp.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/chr_exp.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/chr_exp.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/chr_exp.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/chr_exp.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjcarr.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjcarr.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjcarr.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjcarr.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjcarr.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjdenn.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjdenn.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjdenn.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjhewi.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cjhewi.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cladam.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cladam.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cladam.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cladam.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cmkirk.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cmkirk.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cowie.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cowie.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cpatki.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cpatki.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cpatki.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cpatki.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cpatki.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cprice.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cprice.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csanch.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csanch.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cshubb.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cshubb.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cshubb.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csjscu.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csjscu.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csjscu.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/csjscu.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwang.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwang.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwang.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwang.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwchoi.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cwchoi.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cywan.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cywan.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/cywan.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dagran.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dah_exp_2.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dah_exp_2.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dakram.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dakram.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dakram.51.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dakram.81.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/damvo.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darda.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darda.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darda.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darda.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darodr.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/darodr.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dav_exp.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dav_exp.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dav_exp.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dcbowe.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dcbowe.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/den_exp.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/den_exp.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfarre.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfhodd.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfhodd.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfhodd.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfhodd.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dfhodd.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dgemen.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dgemen.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dgemen.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dioann.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dioann.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dioann.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dioann.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djbirc.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djbirc.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djevan.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djevan.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djevan.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djhugh.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djhugh.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djmart.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djmart.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djmart.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djmart.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djmart.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djotto.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djpben.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djpben.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/djtye.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dlwise.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dlwise.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmcdow.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmcdow.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmcdow.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmwest.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmwest.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dmwest.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dnoguy.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dnoguy.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/dnoguy.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/doraj.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/doraj.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/drbost.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ekavaz.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ekavaz.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ekavaz.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ekavaz.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/elalio.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/elduns.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/elduns.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/filip57707.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/filip57707.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/filip57707.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fmquaz.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fmquaz.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fmquaz.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fmquaz.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fordj.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fordj.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fordj.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/fordj.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdhatc.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdsamp.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gdsamp.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gfilip.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gfilip.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gfilip.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggeorg.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggeorg.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gghazv.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggrego.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggrego.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggrego.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggrego.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ggrego.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gjbods.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gjbods.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gjhero.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gjhero.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gjhero.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/glen_exp.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/glen_exp.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/glen_exp.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gllong.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gllong.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gllong.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gllong.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmagul.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmidgl.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmidgl.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmidgl.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmidgl.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmwate.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gmwate.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpapaz.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpapaz.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpapaz.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpreec.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpsmit.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpsmit.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gpsmit.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsmall.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsmall.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsmall.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gsreas.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/gstamo.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hartb.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hartb.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hartb.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hcarpe.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hensm.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hensm.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hensm.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hensm.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hmgula.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hmgula.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hmgula.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hmgula.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hmgula.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/howar.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/howar.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/howar.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hsgrim.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hsgrim.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hwyman.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hwyman.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/hwyman.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ian_exp.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ian_exp.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ian_exp.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/icolli.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/icolli.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/icolli.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/icolli.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/icolli.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/idsizm.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/idsizm.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/idsizm.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ieorf.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ieorf.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ieorf.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ieorf.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ihopki.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ihopki.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ihopki.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ijfran.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ijfran.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ijfran.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ijfran.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/irdrew.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/irdrew.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/irdrew.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/irdrew.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/irdrew.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ireloz.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ireloz.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ireloz.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ireloz.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/isbald.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/isbald.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/isbald.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/isbald.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ischou.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ischou.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jabins.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jabins.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jagrif.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jagrif.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jbgood.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jcarte.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jcarte.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jcarte.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jdbenm.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jdbenm.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jdbenm.17.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jdbenm.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jedphi.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jedphi.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jepott.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jer_2.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jgelln.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jgelln.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jgloma.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jgloma.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jgloma.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jjdacl.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/jjkeho.10.jpg.
# ...
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/sjcutt.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/sjkill.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/skumar.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/skumar.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/slbirc.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/slbirc.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smalga.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smalga.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smfarrf.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smfarrf.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smille.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smille.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smredh.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/smrobb.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/snhopp.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/snhopp.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spacl.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spacl.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spacl.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spletc.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spyount.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spyount.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/spyount.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ste_exp.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ste_exp.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/ste_exp.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/stu_exp.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/stu_exp.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/stu_exp.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/svkriz.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/svkriz.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swewin.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swewin.3.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swren.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swren.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swren.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swsmit.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swsmit.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/swsmit.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/theoc.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/theoc.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/theod.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/theod.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/theod.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/thgear.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/thgear.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tjdyke.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tjdyke.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tjdyke.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tjdyke.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tjpret.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.10.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.7.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/todris.8.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tom_exp.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tthurs.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tthurs.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/tthurs.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/vanta.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/vanta.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/virvi.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/virvi.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/virvi.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/voudcx.14.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/voudcx.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/vpsavo.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/vpsavo.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/vstros.15.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wardcy.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wardcy.19.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wardcy.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/whussa.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/whussa.18.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/whussa.9.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/will_exp.1.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/will_exp.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/will_exp.6.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjalbe.13.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjalbe.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjhugh.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjhugh.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjhugh.4.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wjsaic.2.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wylsow.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wylsow.20.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/wylsow.5.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/yfhsie.11.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/yfhsie.12.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/yfhsie.16.jpg.
# checkdir error:  cannot create FaceData8000
#                  Transport endpoint is not connected
#                  unable to process FaceData8000/yfhsie.jpg.

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
# Note GENERATE_RES 4 or higher  
# will blow Google CoLab's memory and have not
# been tested extensivly.
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 6
PREVIEW_COLS = 9
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/FaceData8000'
EPOCHS = 100
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %% [markdown]
# Next we will load and preprocess the images.  This can take awhile.  Google CoLab took around an hour to process.  Because of this we store the processed file as a binary.  This way we can simply reload the processed training data and quickly use it.  It is most efficient to only perform this operation once.  The dimensions of the image are encoded into the filename of the binary file because we need to regenerate it if these change.

# %%
# Image set has 11,682 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.
# Note, that file is large enough to cause problems for 
# sume verisons of Pickle,
# so Numpy binary files are used.
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/FaceData8000/training_data_96_96.npy
# Loading previous training pickle...

# %% [markdown]
# We will use a TensorFlow **Dataset** object to actually hold the images.  This allows the data to be quickly shuffled int divided into the appropriate batch sizes for training.

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
    .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# The code below creates the generator and discriminator.

# %% [markdown]
# Next we actually build the discriminator and the generator.  Both will be trained with the Adam optimizer.

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %% [markdown]
# As we progress through training images will be produced to show the progress.  These images will contain a number of rendered faces that show how good the generator has become.  These faces will be

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = '/content/drive/My Drive/projects/output'
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.50131476]], shape=(1, 1), dtype=float32)

# %% [markdown]
# Loss functions must be developed that allow the generator and discriminator to be trained in an adversarial way.  Because these two neural networks are being trained independently they must be trained in two separate passes.  This requires two separate loss functions and also two separate updates to the gradients.  When the discriminator's gradients are applied to decrease the discriminator's loss it is important that only the discriminator's weights are update.  It is not fair, nor will it produce good results, to adversarially damage the weights of the generator to help the discriminator.  A simple backpropagation would do this.  It would simultaneously affect the weights of both generator and discriminator to lower whatever loss it was assigned to lower.
#
# Figure 7.TDIS shows how the discriminator is trained.
#
# **Figure 7.TDIS: Training the Discriminator**
# ![Training the Discriminator](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/gan_fig_2.png "Training the Discriminator")
#
# Here a training set is generated with an equal number of real and fake images.  The real images are randomly sampled (chosen) from the training data.  An equal number of random images are generated from random seeds.  For the discriminator training set, the $x$ contains the input images and the $y$ contains a value of 1 for real images and 0 for generated ones.
#
# Likewise, the Figure 7.TGEN shows how the generator is trained.
#
# **Figure 7.TGEN: Training the Generator**
# ![Training the Generator](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/gan_fig_3.png "Training the Generator")
#
# For the generator training set, the $x$ contains the random seeds to generate images and the $y$ always contains the value of 1, because the optimal is for the generator to have generated such good images that the discriminiator was fooled into assigning them a probability near 1.

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# Both the generator and discriminator use Adam and the same learning rate and momentum.  This does not need to be the case.  If you use a **GENERATE_RES** greater than 3 you may need to tune these learning rates, as well as other training and hyperparameters.

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %% [markdown]
# The following function is where most of the training takes place for both the discriminator and the generator.  This function was based on the GAN provided by the [TensorFlow Keras exmples](https://www.tensorflow.org/tutorials/generative/dcgan) documentation.  The first thing you should notice about this function is that it is annotated with the **tf.function** annotation.  This causes the function to be precompiled and improves performance.
#
# This function trans differently than the code we previously saw for training.  This code makes use of **GradientTape** to allow the discriminator and generator to be trained together, yet separately.

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=0.6722611784934998,disc loss=1.2014362812042236, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=0.6602323055267334,disc loss=1.1515891551971436, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=0.669582188129425,disc loss=1.092348337173462, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=0.6662232279777527,disc loss=1.0984108448028564, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=0.6681216359138489,disc loss=1.1019482612609863, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=0.6709369421005249,disc loss=1.0791773796081543, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=0.6760041117668152,disc loss=1.070189118385315, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=0.680004894733429,disc loss=1.0551750659942627, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=0.6931437253952026,disc loss=1.0065091848373413, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=0.6931389570236206,disc loss=1.006464958190918, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=0.6931138634681702,disc loss=1.0065048933029175, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=0.6931185126304626,disc loss=1.0065250396728516, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=0.6780226826667786,disc loss=1.0745463371276855, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=0.6833675503730774,disc loss=1.0518558025360107, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=0.6825491786003113,disc loss=1.0426630973815918, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=0.6898314952850342,disc loss=1.0235165357589722, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=0.6866058111190796,disc loss=1.0308200120925903, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=0.6789935231208801,disc loss=1.0617069005966187, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=0.6771879196166992,disc loss=1.0658221244812012, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=0.675166666507721,disc loss=1.0654011964797974, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=0.6896041631698608,disc loss=1.0185881853103638, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=0.6767462491989136,disc loss=1.0673524141311646, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=0.6750458478927612,disc loss=1.0755897760391235, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=0.6824105978012085,disc loss=1.0442190170288086, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=0.6783053874969482,disc loss=1.0620191097259521, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=0.6923532485961914,disc loss=1.0089282989501953, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=0.6931456327438354,disc loss=1.0064506530761719, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=0.6931458711624146,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=0.6931367516517639,disc loss=1.0064188241958618, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=0.6931461095809937,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=0.6931459903717041,disc loss=1.0064092874526978, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=0.6931460499763489,disc loss=1.0064094066619873, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=0.6931460499763489,disc loss=1.0064088106155396, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=0.6931458711624146,disc loss=1.0064095258712769, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=0.6931458115577698,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}

# %%
Model_PATH  = '/content/drive/My Drive/projects'
generator.save(os.path.join(Model_PATH ,"face_generator5by7.h5"))

# %%
# !git clone https://git.ffmpeg.org/ffmpeg.git ffmpeg
# Out:
# Cloning into 'ffmpeg'...
# remote: Counting objects: 608155, done.
# remote: Compressing objects: 100% (124920/124920), done.
# remote: Total 608155 (delta 488550), reused 600207 (delta 481990)
# Receiving objects: 100% (608155/608155), 142.37 MiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (488550/488550), done.

# %%
# %cd '/content/drive/My Drive/projects/output/'
# !ffmpeg -r 30 -i 'train-%.png' -vcodec mpeg4 -y movie.mp4
# Out:
# /content/drive/My Drive/projects/output
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# train-%.png: No such file or directory

# %%
# !ffmpeg -r 30 -i image%d.png -vcodec mpeg4 -y movie.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# [image2 @ 0x556eeeb26000] Could find no file with path 'image%d.png' and index in the range 0-4
# image%d.png: No such file or directory

# %%
# !ffmpeg

# %%
# !zip '/content/drive/My Drive/output/' '/content/output.zip'
# Out:
# 	zip warning: name not matched: /content/output.zip
#
# zip error: Nothing to do! (/content/drive/My Drive/output/.zip)
